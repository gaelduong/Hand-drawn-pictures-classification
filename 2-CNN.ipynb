# %% [markdown]
# ## Use CNN to classify hand-drawn pictures (best model)

# %% [markdown]
# <img src="img/cnn.jpg" align='left'>

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint,EarlyStopping
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# PERSONAL NOTES:
#
# Input (1 example): 2D array of pixels
#
# Output (1 example) : array of votes (predicted label = one with highest vote)
#
# CNN applies backpropagation using gradient descent => batch size (# of trainning examples utilised in 1 iteration)
#
# --Factors which affect the model--
#
# + Convolution: # of features/filters + size of features
#
# + Max pooling: window size + window stride
#
# + Fully connected layer: # of neurons of intermidiate layers
#
# + Architecture: How many of each type layer + what order
#
# + Number of Dropout layers & Dropout values
#
# + etc.
#
# Rule of thumb: if your data still useful after swapping the colums/rows then CNN is not for it
#
# *Strides = how many pixels the pooling window move accross the filtered image
#
# *reLU: activation function
#
# *Batch size = the number of training examples utilised in one iteration
#
# *Channel = 3 if RGB elif = 1 if grayscale (in our case it's the latter)
#
# *Dropout = dropout randomly switches off some neurons in the network which forces the data to find new paths.
#     Therefore, this reduces overfitting

# %%
# make dict {0:"sink",1:"pear",...} 
categories=["sink","pear","moustache","nose","skateboard","penguin","peanut","skull","panda","paintbrush","nail","apple","rifle","mug","sailboat","pineapple","spoon","rabbit","shovel","rollerskates","screwdriver","scorpion","rhinoceros","pool","octagon","pillow","parrot","squiggle","mouth","empty","pencil"]
categories_dict = dict(enumerate(categories))
print(categories_dict)
# Out:
# {0: 'sink', 1: 'pear', 2: 'moustache', 3: 'nose', 4: 'skateboard', 5: 'penguin', 6: 'peanut', 7: 'skull', 8: 'panda', 9: 'paintbrush', 10: 'nail', 11: 'apple', 12: 'rifle', 13: 'mug', 14: 'sailboat', 15: 'pineapple', 16: 'spoon', 17: 'rabbit', 18: 'shovel', 19: 'rollerskates', 20: 'screwdriver', 21: 'scorpion', 22: 'rhinoceros', 23: 'pool', 24: 'octagon', 25: 'pillow', 26: 'parrot', 27: 'squiggle', 28: 'mouth', 29: 'empty', 30: 'pencil'}

# %%
#Run this code to extract xTrain.npy, xTest.npy, yTrain.npy
! unzip data.zip
# Out:
# Archive:  data_new_smaller.zip
# replace x_test_38.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## Load data

# %%
# Load data
xTrain = np.load('xTrain.npy')
yTrain = np.array(np.load('yTrain.npy'))
print('Train data size: ',len(xTrain))
print('Train data shape: ', xTrain.shape)
xTest = np.load('xTest.npy')
print ('Test data size: ', len(xTest))
# Out:
# Train data size:  10000
# Train data shape:  (10000, 1444)
# Test data size:  10000

# %%
#Batch size
batch_size = 200
#Number of classes
numClasses = 31
#Number of epochs
epochs = 200

# %% [markdown]
# ## Prepare our inputs
# - Split data into train and validation set
# - Convert yTrain to binary class matrices

# %%
# dimensions of images
rows, cols = 38, 38

# split data into train and validation sets
x_train, x_valid, y_train, y_valid = train_test_split(xTrain, yTrain,test_size=0.20,random_state=0)

x_train = x_train.reshape(8000,rows,cols,1)
x_valid = x_valid.reshape(2000,rows,cols,1)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_valid.shape[0], 'test samples')

# convert class vectors to binary class matrices
# 2 => [0,0,1,0,0,....]
# 0 => [1,0,0,0,0,....]
y_train = keras.utils.to_categorical(y_train, numClasses)
y_valid = keras.utils.to_categorical(y_valid, numClasses)
# Out:
# x_train shape: (8000, 38, 38, 1)
# 8000 train samples
# 2000 test samples

# %% [markdown]
# ## BUILD CNN MODEL

# %%
#MODEL

# --- BUILD NETWORK ---
model = Sequential()
# 3 Convo Layers and 1 Pool layer (+Dropout)
model.add(Conv2D(92, (2, 2), padding='same', activation='relu', input_shape=(rows,cols,1)))
model.add(Conv2D(100, (2, 2), activation='relu'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (2, 2), padding='same', activation='relu'))
# Add dropout randomly switches off some neurons in the network 
# Avoid overfitting

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

# 3 Convo Layers and 1 Pool layer (+Dropout)
model.add(Conv2D(92, (2, 2), padding='same', activation='relu'))
model.add(Conv2D(100, (2, 2), activation='relu'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (2, 2), padding='same', activation='relu'))
# Add dropout randomly switches off some neurons in the network 
# Avoid overfitting

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

#Fully connected layers
#Flatten
model.add(Flatten())
model.add(Dense(512, activation='relu'))
# Add dropout randomly switches off some neurons in the network 
# Avoid overfitting
model.add(Dropout(0.5))

# Dense layers at the end which are used for class prediction
model.add(Dense(31, activation='softmax'))

# %%
#---COMPILE MODEL---
learning_rates =[1,0.1,0.01,0.001,0.0001] #tried all of them and found out 0.001 is the best
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=learning_rate[3]),
              metrics=['accuracy'])

#---AUGMENT DATA---
from keras.preprocessing.image import ImageDataGenerator

# Flippwing & Randomly shifting/rotating/shearing images to create more variations
datagen = ImageDataGenerator(
    rotation_range=5,
    shear_range = 2.2,
    width_shift_range=4.5,
    height_shift_range=4.7,
    horizontal_flip=True)

datagen.fit(x_train)

# Create ModelCheckpoint to save the best model only
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
#callbacks_list = [EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10),checkpoint]
callbacks_list = [checkpoint]

#---TRAIN MODEL---
# Generate augmented data on the fly
model.fit_generator(datagen.flow(x_train, y_train, batch_size=100),
                    validation_data=(x_valid,y_valid),
                    callbacks=callbacks_list,
                    steps_per_epoch=len(x_train)/32, epochs=epochs)

# Evaluate on the validation test
score = model.evaluate(x_valid, y_valid, verbose=0)
#Validation loss
print('Validation loss:', score[0])
#Validation accuracy
print('Validation accuracy:', score[1])
# Out:
# Epoch 1/120
# 250/250 [==============================] - 30s 119ms/step - loss: 0.3687 - acc: 0.8854 - val_loss: 0.7090 - val_acc: 0.8480
#
# Epoch 00001: val_acc improved from -inf to 0.84800, saving model to weights.best.hdf5
# Epoch 2/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3711 - acc: 0.8818 - val_loss: 0.7244 - val_acc: 0.8455
#
# Epoch 00002: val_acc did not improve from 0.84800
# Epoch 3/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3679 - acc: 0.8831 - val_loss: 0.7008 - val_acc: 0.8480
#
# Epoch 00003: val_acc did not improve from 0.84800
# Epoch 4/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3672 - acc: 0.8844 - val_loss: 0.7491 - val_acc: 0.8500
#
# Epoch 00004: val_acc improved from 0.84800 to 0.85000, saving model to weights.best.hdf5
# Epoch 5/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3704 - acc: 0.8836 - val_loss: 0.7426 - val_acc: 0.8445
#
# Epoch 00005: val_acc did not improve from 0.85000
# Epoch 6/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3689 - acc: 0.8857 - val_loss: 0.7114 - val_acc: 0.8440
#
# Epoch 00006: val_acc did not improve from 0.85000
# Epoch 7/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3602 - acc: 0.8870 - val_loss: 0.7344 - val_acc: 0.8415
#
# Epoch 00007: val_acc did not improve from 0.85000
# Epoch 8/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3631 - acc: 0.8884 - val_loss: 0.7036 - val_acc: 0.8490
#
# Epoch 00008: val_acc did not improve from 0.85000
# Epoch 9/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3607 - acc: 0.8855 - val_loss: 0.7266 - val_acc: 0.8465
#
# Epoch 00009: val_acc did not improve from 0.85000
# Epoch 10/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3609 - acc: 0.8842 - val_loss: 0.7063 - val_acc: 0.8430
#
# Epoch 00010: val_acc did not improve from 0.85000
# Epoch 11/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3597 - acc: 0.8852 - val_loss: 0.7434 - val_acc: 0.8440
#
# Epoch 00011: val_acc did not improve from 0.85000
# Epoch 12/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3657 - acc: 0.8839 - val_loss: 0.7305 - val_acc: 0.8450
#
# Epoch 00012: val_acc did not improve from 0.85000
# Epoch 13/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3569 - acc: 0.8858 - val_loss: 0.7272 - val_acc: 0.8445
#
# Epoch 00013: val_acc did not improve from 0.85000
# Epoch 14/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3631 - acc: 0.8854 - val_loss: 0.7323 - val_acc: 0.8470
#
# Epoch 00014: val_acc did not improve from 0.85000
# Epoch 15/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3557 - acc: 0.8886 - val_loss: 0.7384 - val_acc: 0.8450
#
# Epoch 00015: val_acc did not improve from 0.85000
# Epoch 16/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3620 - acc: 0.8863 - val_loss: 0.7298 - val_acc: 0.8380
#
# Epoch 00016: val_acc did not improve from 0.85000
# Epoch 17/120
# 250/250 [==============================] - 29s 115ms/step - loss: 0.3490 - acc: 0.8909 - val_loss: 0.7349 - val_acc: 0.8435
#
# Epoch 00017: val_acc did not improve from 0.85000
# Epoch 18/120
# 250/250 [==============================] - 29s 115ms/step - loss: 0.3461 - acc: 0.8904 - val_loss: 0.7008 - val_acc: 0.8430
#
# Epoch 00018: val_acc did not improve from 0.85000
# Epoch 19/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3673 - acc: 0.8837 - val_loss: 0.7204 - val_acc: 0.8480
#
# Epoch 00019: val_acc did not improve from 0.85000
# Epoch 20/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3490 - acc: 0.8903 - val_loss: 0.7485 - val_acc: 0.8435
#
# Epoch 00020: val_acc did not improve from 0.85000
# Epoch 21/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3543 - acc: 0.8872 - val_loss: 0.7437 - val_acc: 0.8445
#
# Epoch 00021: val_acc did not improve from 0.85000
# Epoch 22/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3476 - acc: 0.8897 - val_loss: 0.7498 - val_acc: 0.8435
#
# Epoch 00022: val_acc did not improve from 0.85000
# Epoch 23/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3456 - acc: 0.8922 - val_loss: 0.7589 - val_acc: 0.8420
#
# Epoch 00023: val_acc did not improve from 0.85000
# Epoch 24/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3547 - acc: 0.8844 - val_loss: 0.7432 - val_acc: 0.8495
#
# Epoch 00024: val_acc did not improve from 0.85000
# Epoch 25/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3454 - acc: 0.8904 - val_loss: 0.7410 - val_acc: 0.8445
#
# Epoch 00025: val_acc did not improve from 0.85000
# Epoch 26/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3449 - acc: 0.8910 - val_loss: 0.7337 - val_acc: 0.8455
#
# Epoch 00026: val_acc did not improve from 0.85000
# Epoch 27/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3495 - acc: 0.8916 - val_loss: 0.7343 - val_acc: 0.8465
#
# Epoch 00027: val_acc did not improve from 0.85000
# Epoch 28/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3441 - acc: 0.8900 - val_loss: 0.7412 - val_acc: 0.8440
#
# Epoch 00028: val_acc did not improve from 0.85000
# Epoch 29/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3554 - acc: 0.8886 - val_loss: 0.7335 - val_acc: 0.8485
#
# Epoch 00029: val_acc did not improve from 0.85000
# Epoch 30/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3519 - acc: 0.8886 - val_loss: 0.7435 - val_acc: 0.8440
#
# Epoch 00030: val_acc did not improve from 0.85000
# Epoch 31/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3572 - acc: 0.8874 - val_loss: 0.7385 - val_acc: 0.8430
#
# Epoch 00031: val_acc did not improve from 0.85000
# Epoch 32/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3394 - acc: 0.8942 - val_loss: 0.7075 - val_acc: 0.8475
#
# Epoch 00032: val_acc did not improve from 0.85000
# Epoch 33/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3494 - acc: 0.8896 - val_loss: 0.7354 - val_acc: 0.8430
#
# Epoch 00033: val_acc did not improve from 0.85000
# Epoch 34/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3430 - acc: 0.8920 - val_loss: 0.7369 - val_acc: 0.8535
#
# Epoch 00034: val_acc improved from 0.85000 to 0.85350, saving model to weights.best.hdf5
# Epoch 35/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3412 - acc: 0.8924 - val_loss: 0.7351 - val_acc: 0.8465
#
# Epoch 00035: val_acc did not improve from 0.85350
# Epoch 36/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3345 - acc: 0.8946 - val_loss: 0.7534 - val_acc: 0.8525
#
# Epoch 00036: val_acc did not improve from 0.85350
# Epoch 37/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3531 - acc: 0.8876 - val_loss: 0.7406 - val_acc: 0.8450
#
# Epoch 00037: val_acc did not improve from 0.85350
# Epoch 38/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3492 - acc: 0.8897 - val_loss: 0.7325 - val_acc: 0.8495
#
# Epoch 00038: val_acc did not improve from 0.85350
# Epoch 39/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3379 - acc: 0.8920 - val_loss: 0.7141 - val_acc: 0.8460
#
# Epoch 00039: val_acc did not improve from 0.85350
# Epoch 40/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3368 - acc: 0.8908 - val_loss: 0.7367 - val_acc: 0.8470
#
# Epoch 00040: val_acc did not improve from 0.85350
# Epoch 41/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3368 - acc: 0.8948 - val_loss: 0.7401 - val_acc: 0.8460
#
# Epoch 00041: val_acc did not improve from 0.85350
# Epoch 42/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3406 - acc: 0.8903 - val_loss: 0.7659 - val_acc: 0.8470
#
# Epoch 00042: val_acc did not improve from 0.85350
# Epoch 43/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3490 - acc: 0.8897 - val_loss: 0.7382 - val_acc: 0.8490
#
# Epoch 00043: val_acc did not improve from 0.85350
# Epoch 44/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3359 - acc: 0.8938 - val_loss: 0.7933 - val_acc: 0.8440
#
# Epoch 00044: val_acc did not improve from 0.85350
# Epoch 45/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3456 - acc: 0.8904 - val_loss: 0.7329 - val_acc: 0.8470
#
# Epoch 00045: val_acc did not improve from 0.85350
# Epoch 46/120
# 250/250 [==============================] - 29s 114ms/step - loss: 0.3364 - acc: 0.8932 - val_loss: 0.7293 - val_acc: 0.8435
#
# Epoch 00046: val_acc did not improve from 0.85350
# Epoch 47/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3424 - acc: 0.8870 - val_loss: 0.7473 - val_acc: 0.8420
#
# Epoch 00047: val_acc did not improve from 0.85350
# Epoch 48/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3383 - acc: 0.8932 - val_loss: 0.7439 - val_acc: 0.8465
#
# Epoch 00048: val_acc did not improve from 0.85350
# Epoch 49/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3413 - acc: 0.8900 - val_loss: 0.7683 - val_acc: 0.8430
#
# Epoch 00049: val_acc did not improve from 0.85350
# Epoch 50/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3359 - acc: 0.8939 - val_loss: 0.7537 - val_acc: 0.8475
#
# Epoch 00050: val_acc did not improve from 0.85350
# Epoch 51/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3427 - acc: 0.8917 - val_loss: 0.7748 - val_acc: 0.8420
#
# Epoch 00051: val_acc did not improve from 0.85350
# Epoch 52/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3256 - acc: 0.8956 - val_loss: 0.7553 - val_acc: 0.8395
#
# Epoch 00052: val_acc did not improve from 0.85350
# Epoch 53/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3347 - acc: 0.8930 - val_loss: 0.7305 - val_acc: 0.8405
#
# Epoch 00053: val_acc did not improve from 0.85350
# Epoch 54/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3337 - acc: 0.8926 - val_loss: 0.7734 - val_acc: 0.8400
#
# Epoch 00054: val_acc did not improve from 0.85350
# Epoch 55/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3342 - acc: 0.8929 - val_loss: 0.7489 - val_acc: 0.8470
#
# Epoch 00055: val_acc did not improve from 0.85350
# Epoch 56/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3309 - acc: 0.8948 - val_loss: 0.7691 - val_acc: 0.8470
#
# Epoch 00056: val_acc did not improve from 0.85350
# Epoch 57/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3293 - acc: 0.8953 - val_loss: 0.7521 - val_acc: 0.8490
#
# Epoch 00057: val_acc did not improve from 0.85350
# Epoch 58/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3334 - acc: 0.8943 - val_loss: 0.7251 - val_acc: 0.8425
#
# Epoch 00058: val_acc did not improve from 0.85350
# Epoch 59/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3437 - acc: 0.8902 - val_loss: 0.7456 - val_acc: 0.8445
#
# Epoch 00059: val_acc did not improve from 0.85350
# Epoch 60/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3345 - acc: 0.8920 - val_loss: 0.8074 - val_acc: 0.8395
#
# Epoch 00060: val_acc did not improve from 0.85350
# Epoch 61/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3345 - acc: 0.8935 - val_loss: 0.7434 - val_acc: 0.8495
#
# Epoch 00061: val_acc did not improve from 0.85350
# Epoch 62/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3304 - acc: 0.8960 - val_loss: 0.7586 - val_acc: 0.8420
#
# Epoch 00062: val_acc did not improve from 0.85350
# Epoch 63/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3315 - acc: 0.8972 - val_loss: 0.7387 - val_acc: 0.8480
#
# Epoch 00063: val_acc did not improve from 0.85350
# Epoch 64/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3287 - acc: 0.8984 - val_loss: 0.7611 - val_acc: 0.8415
#
# Epoch 00064: val_acc did not improve from 0.85350
# Epoch 65/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3275 - acc: 0.8952 - val_loss: 0.7620 - val_acc: 0.8450
#
# Epoch 00065: val_acc did not improve from 0.85350
# Epoch 66/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3262 - acc: 0.8963 - val_loss: 0.7856 - val_acc: 0.8400
#
# Epoch 00066: val_acc did not improve from 0.85350
# Epoch 67/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3269 - acc: 0.8986 - val_loss: 0.8081 - val_acc: 0.8380
#
# Epoch 00067: val_acc did not improve from 0.85350
# Epoch 68/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3279 - acc: 0.8951 - val_loss: 0.7864 - val_acc: 0.8475
#
# Epoch 00068: val_acc did not improve from 0.85350
# Epoch 69/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3283 - acc: 0.8948 - val_loss: 0.7733 - val_acc: 0.8500
#
# Epoch 00069: val_acc did not improve from 0.85350
# Epoch 70/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3371 - acc: 0.8933 - val_loss: 0.7847 - val_acc: 0.8420
#
# Epoch 00070: val_acc did not improve from 0.85350
# Epoch 71/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3397 - acc: 0.8926 - val_loss: 0.7755 - val_acc: 0.8490
#
# Epoch 00071: val_acc did not improve from 0.85350
# Epoch 72/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3277 - acc: 0.8964 - val_loss: 0.7725 - val_acc: 0.8485
#
# Epoch 00072: val_acc did not improve from 0.85350
# Epoch 73/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3269 - acc: 0.8958 - val_loss: 0.7566 - val_acc: 0.8470
#
# Epoch 00073: val_acc did not improve from 0.85350
# Epoch 74/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3262 - acc: 0.8967 - val_loss: 0.7725 - val_acc: 0.8450
#
# Epoch 00074: val_acc did not improve from 0.85350
# Epoch 75/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3217 - acc: 0.8987 - val_loss: 0.7362 - val_acc: 0.8470
#
# Epoch 00075: val_acc did not improve from 0.85350
# Epoch 76/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3374 - acc: 0.8943 - val_loss: 0.7563 - val_acc: 0.8475
#
# Epoch 00076: val_acc did not improve from 0.85350
# Epoch 77/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3201 - acc: 0.9003 - val_loss: 0.7396 - val_acc: 0.8510
#
# Epoch 00077: val_acc did not improve from 0.85350
# Epoch 78/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3162 - acc: 0.8997 - val_loss: 0.7709 - val_acc: 0.8490
#
# Epoch 00078: val_acc did not improve from 0.85350
# Epoch 79/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3223 - acc: 0.8982 - val_loss: 0.7649 - val_acc: 0.8450
#
# Epoch 00079: val_acc did not improve from 0.85350
# Epoch 80/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3244 - acc: 0.8973 - val_loss: 0.7706 - val_acc: 0.8405
#
# Epoch 00080: val_acc did not improve from 0.85350
# Epoch 81/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3297 - acc: 0.8953 - val_loss: 0.7683 - val_acc: 0.8460
#
# Epoch 00081: val_acc did not improve from 0.85350
# Epoch 82/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3311 - acc: 0.8948 - val_loss: 0.7666 - val_acc: 0.8505
#
# Epoch 00082: val_acc did not improve from 0.85350
# Epoch 83/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3294 - acc: 0.8956 - val_loss: 0.7448 - val_acc: 0.8485
#
# Epoch 00083: val_acc did not improve from 0.85350
# Epoch 84/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3216 - acc: 0.8982 - val_loss: 0.7597 - val_acc: 0.8445
#
# Epoch 00084: val_acc did not improve from 0.85350
# Epoch 85/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3325 - acc: 0.8955 - val_loss: 0.7622 - val_acc: 0.8505
#
# Epoch 00085: val_acc did not improve from 0.85350
# Epoch 86/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3192 - acc: 0.8994 - val_loss: 0.7989 - val_acc: 0.8420
#
# Epoch 00086: val_acc did not improve from 0.85350
# Epoch 87/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3154 - acc: 0.8981 - val_loss: 0.7622 - val_acc: 0.8455
#
# Epoch 00087: val_acc did not improve from 0.85350
# Epoch 88/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3215 - acc: 0.8978 - val_loss: 0.7808 - val_acc: 0.8460
#
# Epoch 00088: val_acc did not improve from 0.85350
# Epoch 89/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3134 - acc: 0.8996 - val_loss: 0.7527 - val_acc: 0.8505
#
# Epoch 00089: val_acc did not improve from 0.85350
# Epoch 90/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3163 - acc: 0.8997 - val_loss: 0.7459 - val_acc: 0.8450
#
# Epoch 00090: val_acc did not improve from 0.85350
# Epoch 91/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3240 - acc: 0.8990 - val_loss: 0.7273 - val_acc: 0.8450
#
# Epoch 00091: val_acc did not improve from 0.85350
# Epoch 92/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3196 - acc: 0.8984 - val_loss: 0.7353 - val_acc: 0.8440
#
# Epoch 00092: val_acc did not improve from 0.85350
# Epoch 93/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3234 - acc: 0.8970 - val_loss: 0.7790 - val_acc: 0.8450
#
# Epoch 00093: val_acc did not improve from 0.85350
# Epoch 94/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3211 - acc: 0.8979 - val_loss: 0.7526 - val_acc: 0.8480
#
# Epoch 00094: val_acc did not improve from 0.85350
# Epoch 95/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3161 - acc: 0.9006 - val_loss: 0.7969 - val_acc: 0.8425
#
# Epoch 00095: val_acc did not improve from 0.85350
# Epoch 96/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3257 - acc: 0.8980 - val_loss: 0.7396 - val_acc: 0.8460
#
# Epoch 00096: val_acc did not improve from 0.85350
# Epoch 97/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3188 - acc: 0.8985 - val_loss: 0.7866 - val_acc: 0.8410
#
# Epoch 00097: val_acc did not improve from 0.85350
# Epoch 98/120
# 250/250 [==============================] - 29s 115ms/step - loss: 0.3075 - acc: 0.9042 - val_loss: 0.7829 - val_acc: 0.8425
#
# Epoch 00098: val_acc did not improve from 0.85350
# Epoch 99/120
# 250/250 [==============================] - 29s 115ms/step - loss: 0.3114 - acc: 0.9011 - val_loss: 0.7678 - val_acc: 0.8440
#
# Epoch 00099: val_acc did not improve from 0.85350
# Epoch 100/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3288 - acc: 0.8967 - val_loss: 0.7638 - val_acc: 0.8470
#
# Epoch 00100: val_acc did not improve from 0.85350
# Epoch 101/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3137 - acc: 0.8985 - val_loss: 0.7677 - val_acc: 0.8550
#
# Epoch 00101: val_acc improved from 0.85350 to 0.85500, saving model to weights.best.hdf5
# Epoch 102/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3120 - acc: 0.8995 - val_loss: 0.7887 - val_acc: 0.8435
#
# Epoch 00102: val_acc did not improve from 0.85500
# Epoch 103/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3182 - acc: 0.9002 - val_loss: 0.7715 - val_acc: 0.8460
#
# Epoch 00103: val_acc did not improve from 0.85500
# Epoch 104/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3236 - acc: 0.8971 - val_loss: 0.7662 - val_acc: 0.8515
#
# Epoch 00104: val_acc did not improve from 0.85500
# Epoch 105/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3126 - acc: 0.9007 - val_loss: 0.7773 - val_acc: 0.8400
#
# Epoch 00105: val_acc did not improve from 0.85500
# Epoch 106/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3151 - acc: 0.9008 - val_loss: 0.7317 - val_acc: 0.8465
#
# Epoch 00106: val_acc did not improve from 0.85500
# Epoch 107/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3131 - acc: 0.8997 - val_loss: 0.7507 - val_acc: 0.8475
#
# Epoch 00107: val_acc did not improve from 0.85500
# Epoch 108/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3055 - acc: 0.9023 - val_loss: 0.7728 - val_acc: 0.8475
#
# Epoch 00108: val_acc did not improve from 0.85500
# Epoch 109/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3173 - acc: 0.8997 - val_loss: 0.7900 - val_acc: 0.8390
#
# Epoch 00109: val_acc did not improve from 0.85500
# Epoch 110/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3196 - acc: 0.8981 - val_loss: 0.7891 - val_acc: 0.8395
#
# Epoch 00110: val_acc did not improve from 0.85500
# Epoch 111/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3152 - acc: 0.9004 - val_loss: 0.7319 - val_acc: 0.8430
#
# Epoch 00111: val_acc did not improve from 0.85500
# Epoch 112/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3100 - acc: 0.9003 - val_loss: 0.7597 - val_acc: 0.8410
#
# Epoch 00112: val_acc did not improve from 0.85500
# Epoch 113/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3174 - acc: 0.9001 - val_loss: 0.7551 - val_acc: 0.8440
#
# Epoch 00113: val_acc did not improve from 0.85500
# Epoch 114/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3123 - acc: 0.8995 - val_loss: 0.7837 - val_acc: 0.8480
#
# Epoch 00114: val_acc did not improve from 0.85500
# Epoch 115/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3101 - acc: 0.9005 - val_loss: 0.7603 - val_acc: 0.8465
#
# Epoch 00115: val_acc did not improve from 0.85500
# Epoch 116/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3173 - acc: 0.8998 - val_loss: 0.7759 - val_acc: 0.8445
#
# Epoch 00116: val_acc did not improve from 0.85500
# Epoch 117/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3117 - acc: 0.9010 - val_loss: 0.7481 - val_acc: 0.8495
#
# Epoch 00117: val_acc did not improve from 0.85500
# Epoch 118/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3074 - acc: 0.9025 - val_loss: 0.7939 - val_acc: 0.8445
#
# Epoch 00118: val_acc did not improve from 0.85500
# Epoch 119/120
# 250/250 [==============================] - 28s 113ms/step - loss: 0.3108 - acc: 0.9020 - val_loss: 0.7732 - val_acc: 0.8360
#
# Epoch 00119: val_acc did not improve from 0.85500
# Epoch 120/120
# 250/250 [==============================] - 28s 114ms/step - loss: 0.3175 - acc: 0.8982 - val_loss: 0.7964 - val_acc: 0.8490
#
# Epoch 00120: val_acc did not improve from 0.85500
# Test loss: 0.7963501101732254
# Test accuracy: 0.849

# %% [markdown]
# After tuning our CNN, we were able to obtain a 85.5% accuracy on the train set and 84.9% on the validation set, which is far better than the standard NN and the baseline classifier SVM.
#
# We obtained 85.34% accuracy on the real test set provided by Kaggle (we are the 4th team - RedWolves):
#
# <img src="img/rank.jpg" align='left'>

# %%
#Load the best model
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer='adam',
              metrics=['accuracy'])
model.load_weights("weights.best.hdf5")

model.evaluate(x_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 1s 601us/step
# [0.7002374560832977, 0.8555]

# %%
# save model (not required)
model.save("cnn_12.model")

# %%
# load model (not required)
new_model = keras.models.load_model("cnn_12.model")
new_model.evaluate(x_valid, y_valid)

# %%
# predict
predictions_cnn = model.predict(xTest.reshape(10000,rows,cols,1))
result = []
for vector in predictions_cnn:
    result.append([np.argmax(vector)])

y_predictions_cnn = np.array(result)

# %%
# Output a few predictions from y_predictions_cnn
print(y_predictions_cnn[0][0])
#print(y_predictions_cnn[2][0])
#print(y_predictions_cnn[123][0])
# Out:
# 15

# %% [markdown]
# ## Output prediction to csv file

# %%
# Write predictions to csv file
# Write (id, dict_labels[each y in y_predictions_cnn])
import csv
with open("predictions_cnn12.csv","w") as f:
    writer = csv.writer(f)
    writer.writerow(["Id","Category"])
    id = 0
    for line in y_predictions_cnn:
        result = [id,categories_dict[line[0]]]
        writer.writerow(result)
        id += 1
